# %%
import numpy as np
v = np.random.rand(5, 10)
Y = v - v.mean(axis=1, keepdims=True)
print(Y)
# Out:
# [[-0.04282348  0.25677614  0.38595646  0.010903    0.15356292  0.23804557
#   -0.21878557 -0.14053592 -0.20756962 -0.43552948]
#  [ 0.3993499  -0.09392838  0.47999682 -0.38200727 -0.47319026 -0.47648511
#    0.07374982  0.29770248  0.34202699 -0.16721499]
#  [ 0.42598221  0.16833989 -0.48803776  0.0159031   0.36644344 -0.25445365
#    0.36199315 -0.38435196  0.21110381 -0.42292222]
#  [-0.05142777  0.07652385  0.46099422  0.07057704 -0.33150626  0.01761968
#    0.34005352 -0.31927862 -0.28161218  0.01805652]
#  [-0.01767     0.04533173  0.14406439 -0.02139927 -0.20383465 -0.47364417
#   -0.19536477  0.02711561  0.33912006  0.35628108]]
