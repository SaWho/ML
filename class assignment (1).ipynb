# %%
import numpy as np
import matplotlib.pyplot as plt
import random


x = []
y = []

for i in range(100):
	a = random.randint(0, 30)
	b = random.randint(0, 10)

	x.append(a)
	y.append(a*3+b)



plt.scatter(x, y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()
