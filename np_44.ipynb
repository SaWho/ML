# %%
import numpy as np
v = np.random.random((10,2))
x,y = v[:,0], v[:,1]
x_p = np.sqrt(x**2+y**2)
y_p = np.arctan2(y,x)
print(x_p)
print(y_p)
# Out:
# [0.95630133 0.9487471  0.54798893 1.18632957 1.14448367 0.9428513
#  1.10385832 0.80448295 0.41777997 0.64309584]
# [0.21129258 0.58306899 0.14049728 0.74095933 0.59663406 1.07436881
#  0.53478084 0.54274316 0.02689191 0.70465925]
