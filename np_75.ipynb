# %%
import numpy as np
def average(a, n=4) :
    v = np.cumsum(a, dtype=float)
    v[n:] = v[n:] - v[:-n]
    return v[n - 1:] / n
w = np.random.randint(1,10,20)
print(average(w, n=4))
# Out:
# [5.5  6.   6.25 5.   5.   3.75 3.75 3.75 3.75 5.25 6.5  7.5  7.5  6.75
#  6.75 7.25 7.  ]
