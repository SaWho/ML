# %%
import numpy as np
v = np.random.random(10)
print(v)
v[v.argmax()] = 0
print(v)
# Out:
# [0.85031427 0.65952292 0.32045238 0.77873234 0.86431029 0.01562098
#  0.09052751 0.9965043  0.03634863 0.42076676]
# [0.85031427 0.65952292 0.32045238 0.77873234 0.86431029 0.01562098
#  0.09052751 0.         0.03634863 0.42076676]
