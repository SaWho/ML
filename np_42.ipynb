# %%
import numpy as np
v=np.random.uniform(0,10,10)
w=np.random.uniform(0,10,10)
print(v)
print(w)
print(np.array_equal(v,w))
# Out:
# [7.58881788 6.73037298 2.82866164 1.63770502 7.02766045 9.31519733
#  8.3749489  6.68667272 4.79974216 0.47424   ]
# [3.69759258 9.16047751 5.56905667 7.33568575 4.82567939 0.10705284
#  3.6539786  7.49236792 2.24218441 4.02280437]
# False
