# %%
import numpy as np
v = np.arange(3).reshape(3,1)
w = np.arange(3).reshape(1,3)
it = np.nditer([v,w,None])
for x,y,z in it: z[...] = x + y
print(it.operands[2])
# Out:
# [[0 1 2]
#  [1 2 3]
#  [2 3 4]]
