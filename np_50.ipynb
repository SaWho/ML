# %%
import numpy as np
w=np.ones(10)*5
v = np.random.uniform(0,100,10)
print(v)
index = (np.abs(v-w)).argmin()
print(v[index])
# Out:
# [62.31861664  6.99132993 30.25049526  4.04733156 68.62532706 65.81761893
#  66.23317778 68.12520075 65.73630205 95.80520591]
# 4.047331562637002
