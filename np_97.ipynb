# %%
import numpy as np
A = np.random.uniform(0,1,10)
B = np.random.uniform(0,1,10)

np.einsum('i->', A)       # np.sum(A)
np.einsum('i,i->i', A, B) # A * B
np.einsum('i,i', A, B)    # np.inner(A, B)
np.einsum('i,j->ij', A, B)    # np.outer(A, B)
# Out:
# array([[0.24306199, 0.22369231, 0.06424437, 0.29576309, 0.33494329,
#         0.40018692, 0.52136256, 0.25419928, 0.33976854, 0.40094974],
#        [0.39077418, 0.35963327, 0.10328658, 0.47550248, 0.53849304,
#         0.64338615, 0.83820192, 0.40867976, 0.54625067, 0.64461253],
#        [0.26827546, 0.24689651, 0.07090861, 0.32644338, 0.36968786,
#         0.44169938, 0.57544489, 0.28056805, 0.37501364, 0.44254132],
#        [0.0405115 , 0.03728313, 0.01070771, 0.04929527, 0.0558255 ,
#         0.06669975, 0.08689628, 0.04236777, 0.05662973, 0.06682689],
#        [0.17764089, 0.16348464, 0.04695275, 0.21615728, 0.24479198,
#         0.29247502, 0.38103576, 0.18578054, 0.24831849, 0.29303252],
#        [0.31001255, 0.28530756, 0.08194026, 0.37722997, 0.42720223,
#         0.51041698, 0.66497002, 0.32421757, 0.43335658, 0.51138991],
#        [0.2592168 , 0.23855974, 0.0685143 , 0.31542061, 0.35720488,
#         0.42678485, 0.55601427, 0.27109432, 0.36235084, 0.42759836],
#        [0.02123534, 0.01954309, 0.00561277, 0.02583962, 0.02926264,
#         0.03496271, 0.04554934, 0.02220836, 0.0296842 , 0.03502935],
#        [0.19246069, 0.17712344, 0.05086981, 0.23419033, 0.26521389,
#         0.31687493, 0.41282389, 0.20127939, 0.26903461, 0.31747894],
#        [0.08194853, 0.07541803, 0.02166004, 0.09971674, 0.11292638,
#         0.13492331, 0.17577777, 0.08570347, 0.11455321, 0.1351805 ]])
