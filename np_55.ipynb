# %%
import numpy as np
Z = np.arange(36).reshape(6,6)
for index, value in np.ndenumerate(Z):
    print(index, value)
# Out:
# (0, 0) 0
# (0, 1) 1
# (0, 2) 2
# (0, 3) 3
# (0, 4) 4
# (0, 5) 5
# (1, 0) 6
# (1, 1) 7
# (1, 2) 8
# (1, 3) 9
# (1, 4) 10
# (1, 5) 11
# (2, 0) 12
# (2, 1) 13
# (2, 2) 14
# (2, 3) 15
# (2, 4) 16
# (2, 5) 17
# (3, 0) 18
# (3, 1) 19
# (3, 2) 20
# (3, 3) 21
# (3, 4) 22
# (3, 5) 23
# (4, 0) 24
# (4, 1) 25
# (4, 2) 26
# (4, 3) 27
# (4, 4) 28
# (4, 5) 29
# (5, 0) 30
# (5, 1) 31
# (5, 2) 32
# (5, 3) 33
# (5, 4) 34
# (5, 5) 35
