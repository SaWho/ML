# %%
import numpy as np
x = np.random.randint(0,2,10)
print(np.logical_not(x, out=x))

w = np.random.uniform(-1.0,1.0,10)
print(np.negative(w, out=w))
# Out:
# [1 1 0 0 1 1 1 0 0 1]
# [-0.03558617  0.66986555  0.12807302 -0.04326508 -0.73251534  0.09534059
#  -0.37439234 -0.04378537 -0.63640961  0.6353476 ]
