# %%
import numpy as np
Z = np.random.random((10,2))
X,Y = np.atleast_2d(Z[:,0], Z[:,1])
D = np.sqrt( (X-X.T)**2 + (Y-Y.T)**2)
print(D)
# Out:
# [[0.         0.77252506 0.06269254 0.15069255 0.08628191 0.03399033
#   0.69945439 1.06383076 0.49184488 0.79038456]
#  [0.77252506 0.         0.71030815 0.91916506 0.69057424 0.79739262
#   1.05314949 0.70561097 0.28176535 1.11905526]
#  [0.06269254 0.71030815 0.         0.21297729 0.02711576 0.08826521
#   0.71088998 1.02318946 0.43004918 0.80174703]
#  [0.15069255 0.91916506 0.21297729 0.         0.23691567 0.13598833
#   0.67426976 1.1547334  0.63756827 0.76274608]
#  [0.08628191 0.69057424 0.02711576 0.23691567 0.         0.10696072
#   0.73132246 1.02169937 0.41152011 0.82204629]
#  [0.03399033 0.79739262 0.08826521 0.13598833 0.10696072 0.
#   0.72289765 1.09779432 0.51777922 0.81368597]
#  [0.69945439 1.05314949 0.71088998 0.67426976 0.73132246 0.72289765
#   0.         0.81147509 0.84751038 0.09097497]
#  [1.06383076 0.70561097 1.02318946 1.1547334  1.02169937 1.09779432
#   0.81147509 0.         0.75030856 0.82083605]
# ...
