# %%
import numpy as np
v = np.random.uniform(-5,+5,8)
print(v)
w=np.ceil(np.abs(v))
print (np.copysign(w, v))
# Out:
# [ 2.45092385  4.19976726 -3.05508613  4.31712063 -3.19316538  0.50990636
#  -0.86406756 -2.77327591]
# [ 3.  5. -4.  5. -4.  1. -1. -3.]
