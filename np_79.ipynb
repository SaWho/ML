# %%
import numpy as np
def distance(P0, P1, p):
    T = P1 - P0
    L = (T**2).sum(axis=1)
    U = -((P0[:,0]-p[...,0])*T[:,0] + (P0[:,1]-p[...,1])*T[:,1]) / L
    U = U.reshape(len(U),1)
    D = P0 + U*T - p
    return np.sqrt((D**2).sum(axis=1))
P0 = np.random.uniform(-10, 10, (10,2))
P1 = np.random.uniform(-10,10,(10,2))
p = np.random.uniform(-10, 10, (10,2))
print(np.array([distance(P0,P1,p_i) for p_i in p]))
# Out:
# [[13.02351208 10.87783014 13.64035956  7.84113289  0.51598338 16.37087101
#    6.69341602 11.3129205   6.15627928  0.90012289]
#  [ 2.30947204  6.11768757  3.20524636  0.48646443 15.81903986  3.23621374
#    0.63382758  2.22555314  6.08143555  9.66642348]
#  [13.73581793  4.43391599  4.30529418 10.29910773 10.85372484  5.70607404
#    9.8191525   0.66551328  1.02991313  1.72749541]
#  [15.77199958 10.29360141 11.13686935 11.2205464   4.00277539 12.20842613
#   10.29552954  7.24789355  1.4811665   3.69228901]
#  [13.79345147  8.39155617  9.73288698  9.37180128  4.97494423 11.6665517
#    8.51164263  6.63299085  2.64136698  1.72059182]
#  [ 3.63491761  0.44848187  5.04040205  0.57856297  7.23373537 11.66105108
#    1.28242179  6.25481442 10.32880608  8.43281809]
#  [17.73531268 11.00685718 10.90923797 13.35027692  4.79843791 10.9574293
#   12.47473221  6.06789651  0.7849206   5.66816247]
#  [ 2.62543257  4.13169972  0.65884822  0.61420782 13.14167086  5.88549052
#    0.93501872  0.43748634  7.49340889  9.37929276]
#  [10.50726542  2.3716569   3.0957844   8.21314158 17.99013123  0.81757955
#    8.19790839  5.98192872  2.65154372  1.42884407]
#  [ 2.29368217  6.4032474   3.58968764  0.43323524 16.23216876  2.81998968
#    0.55386793  2.64269764  5.83397495  9.67770081]]
